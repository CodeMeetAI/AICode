# %%
import json
import pandas as pd

# %%
data = json.load(open("/home/eidf018/eidf018/s2484588-epcc/MLP/LLMMemoryEval/datasets/data/multiwoz/original_data/test/dialogues_001.json", 'r'))

# %%
train_departure_destination = []
for dialogue in data:
    train_departure_destination_dialogue = []
    turns = dialogue['turns']
    for turn in turns:
        if turn['speaker'] == "SYSTEM":
            continue
        frames = turn['frames']
        for topic in frames:
            if topic['state']['active_intent'] != "NONE":
                _ = list(topic['state']['slot_values'].keys())
                if len(_) > 0:
                    train_departure_destination_dialogue.append(_)
    train_departure_destination.append(train_departure_destination_dialogue)

# %%
train_departure_destination[0]
# Out:
# [['train-departure', 'train-destination'],
#  ['train-arriveby', 'train-day', 'train-departure', 'train-destination'],
#  ['train-arriveby', 'train-day', 'train-departure', 'train-destination'],
#  ['attraction-name']]

# %%
from collections import Counter

# %%
def find_series(sample):
    element_counts = Counter(list(map(lambda x: tuple(x), sample)))
    repeated_tuples = [element for element, count in element_counts.items() if count >= 2]
    
    return repeated_tuples

# %%
record = []
for i, sample in enumerate(train_departure_destination):
    repeat = find_series(sample)
    if len(repeat) != 0:
        record.extend(repeat)

# %%
Counter(record)
# Out:
# Counter({('train-arriveby',
#           'train-day',
#           'train-departure',
#           'train-destination'): 71,
#          ('attraction-area', 'attraction-type'): 71,
#          ('restaurant-area',
#           'restaurant-bookday',
#           'restaurant-bookpeople',
#           'restaurant-booktime',
#           'restaurant-food',
#           'restaurant-name',
#           'restaurant-pricerange'): 39,
#          ('restaurant-area', 'restaurant-food', 'restaurant-pricerange'): 37,
#          ('train-day',
#           'train-departure',
#           'train-destination',
#           'train-leaveat'): 33,
#          ('attraction-name',): 26,
#          ('attraction-area', 'attraction-name', 'attraction-type'): 24,
#          ('attraction-type',): 20,
#          ('restaurant-area', 'restaurant-food'): 20,
#          ('attraction-area',): 20,
#          ('restaurant-name',): 18,
#          ('restaurant-food', 'restaurant-pricerange'): 17,
#          ('restaurant-area',
#           'restaurant-food',
#           'restaurant-name',
#           'restaurant-pricerange'): 16,
#          ('train-bookpeople',
#           'train-day',
#           'train-departure',
#           'train-destination',
#           'train-leaveat'): 15,
#          ('taxi-departure', 'taxi-destination', 'taxi-leaveat'): 14,
#          ('hotel-name',): 14,
#          ('train-arriveby',
#           'train-bookpeople',
#           'train-day',
#           'train-departure',
#           'train-destination'): 13,
#          ('restaurant-area', 'restaurant-pricerange'): 11,
#          ('restaurant-bookday',
#           'restaurant-bookpeople',
#           'restaurant-booktime',
#           'restaurant-name'): 10,
#          ('taxi-arriveby', 'taxi-departure', 'taxi-destination'): 8,
#          ('attraction-name', 'attraction-type'): 8,
#          ('hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-name'): 8,
#          ('restaurant-area', 'restaurant-food', 'restaurant-name'): 7,
#          ('train-arriveby',
#           'train-day',
#           'train-departure',
#           'train-destination',
#           'train-leaveat'): 7,
#          ('attraction-area', 'attraction-name'): 6,
#          ('restaurant-bookday',
#           'restaurant-bookpeople',
#           'restaurant-booktime',
#           'restaurant-food',
#           'restaurant-name',
#           'restaurant-pricerange'): 6,
#          ('train-arriveby',
#           'train-bookpeople',
#           'train-day',
#           'train-departure',
#           'train-destination',
#           'train-leaveat'): 5,
#          ('hotel-area', 'hotel-internet', 'hotel-pricerange', 'hotel-type'): 5,
#          ('hotel-area', 'hotel-parking', 'hotel-pricerange', 'hotel-type'): 4,
#          ('restaurant-area',
#           'restaurant-bookday',
#           'restaurant-bookpeople',
#           'restaurant-booktime',
#           'restaurant-name',
#           'restaurant-pricerange'): 4,
#          ('hotel-area', 'hotel-pricerange', 'hotel-type'): 4,
#          ('hotel-area', 'hotel-pricerange', 'hotel-stars', 'hotel-type'): 3,
#          ('train-day', 'train-departure', 'train-destination'): 3,
#          ('hotel-area', 'hotel-parking', 'hotel-pricerange', 'hotel-stars'): 3,
#          ('hotel-parking', 'hotel-pricerange', 'hotel-type'): 3,
#          ('train-arriveby', 'train-day', 'train-destination'): 3,
#          ('restaurant-food',): 3,
#          ('restaurant-area',
#           'restaurant-bookday',
#           'restaurant-bookpeople',
#           'restaurant-booktime',
#           'restaurant-food',
#           'restaurant-pricerange'): 3,
#          ('hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-internet',
#           'hotel-name',
#           'hotel-parking',
#           'hotel-pricerange',
#           'hotel-type'): 2,
#          ('hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-name',
#           'hotel-pricerange',
#           'hotel-stars',
#           'hotel-type'): 2,
#          ('hotel-area',
#           'hotel-internet',
#           'hotel-parking',
#           'hotel-stars',
#           'hotel-type'): 2,
#          ('hotel-area',
#           'hotel-internet',
#           'hotel-name',
#           'hotel-parking',
#           'hotel-pricerange',
#           'hotel-stars'): 2,
#          ('hotel-name', 'hotel-parking', 'hotel-pricerange', 'hotel-stars'): 2,
#          ('hotel-pricerange', 'hotel-stars'): 2,
#          ('hotel-area',
#           'hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-name',
#           'hotel-parking',
#           'hotel-pricerange',
#           'hotel-stars'): 2,
#          ('hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-internet',
#           'hotel-name',
#           'hotel-pricerange',
#           'hotel-stars',
#           'hotel-type'): 2,
#          ('hotel-area',
#           'hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-name',
#           'hotel-pricerange',
#           'hotel-stars'): 2,
#          ('hotel-area',
#           'hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-name',
#           'hotel-pricerange',
#           'hotel-stars',
#           'hotel-type'): 2,
#          ('hotel-area',
#           'hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-internet',
#           'hotel-name',
#           'hotel-pricerange',
#           'hotel-type'): 2,
#          ('hotel-area', 'hotel-internet', 'hotel-parking', 'hotel-stars'): 2,
#          ('restaurant-bookday',
#           'restaurant-bookpeople',
#           'restaurant-booktime',
#           'restaurant-food',
#           'restaurant-pricerange'): 2,
#          ('hotel-area',
#           'hotel-internet',
#           'hotel-parking',
#           'hotel-pricerange',
#           'hotel-type'): 2,
#          ('hotel-parking', 'hotel-stars', 'hotel-type'): 2,
#          ('hotel-area',
#           'hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-internet',
#           'hotel-name',
#           'hotel-pricerange',
#           'hotel-stars'): 2,
#          ('restaurant-food', 'restaurant-name', 'restaurant-pricerange'): 2,
#          ('train-arriveby', 'train-destination'): 2,
#          ('train-day', 'train-departure', 'train-leaveat'): 2,
#          ('hotel-area',
#           'hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-name',
#           'hotel-parking'): 2,
#          ('hotel-area', 'hotel-parking', 'hotel-pricerange'): 2,
#          ('hotel-area',
#           'hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-internet',
#           'hotel-name',
#           'hotel-parking',
#           'hotel-pricerange',
#           'hotel-stars',
#           'hotel-type'): 2,
#          ('hotel-area',
#           'hotel-internet',
#           'hotel-pricerange',
#           'hotel-stars',
#           'hotel-type'): 2,
#          ('hotel-internet', 'hotel-pricerange', 'hotel-stars'): 2,
#          ('hotel-area',
#           'hotel-internet',
#           'hotel-parking',
#           'hotel-pricerange',
#           'hotel-stars'): 2,
#          ('hotel-area',
#           'hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-internet',
#           'hotel-name',
#           'hotel-parking',
#           'hotel-stars',
#           'hotel-type'): 2,
#          ('hotel-area', 'hotel-stars', 'hotel-type'): 1,
#          ('hotel-area', 'hotel-stars'): 1,
#          ('hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-internet',
#           'hotel-pricerange',
#           'hotel-stars'): 1,
#          ('hotel-name', 'hotel-type'): 1,
#          ('train-bookpeople', 'train-departure', 'train-leaveat'): 1,
#          ('hotel-area',
#           'hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-internet',
#           'hotel-name',
#           'hotel-stars',
#           'hotel-type'): 1,
#          ('train-day', 'train-departure'): 1,
#          ('hotel-area', 'hotel-internet', 'hotel-type'): 1,
#          ('hotel-area',
#           'hotel-internet',
#           'hotel-name',
#           'hotel-parking',
#           'hotel-stars',
#           'hotel-type'): 1,
#          ('hotel-name', 'hotel-pricerange', 'hotel-stars', 'hotel-type'): 1,
#          ('hotel-internet', 'hotel-parking', 'hotel-type'): 1,
#          ('hotel-area',
#           'hotel-internet',
#           'hotel-name',
#           'hotel-pricerange',
#           'hotel-type'): 1,
#          ('taxi-arriveby', 'taxi-destination'): 1,
#          ('hotel-internet',
#           'hotel-parking',
#           'hotel-pricerange',
#           'hotel-stars'): 1,
#          ('hotel-area', 'hotel-name', 'hotel-pricerange', 'hotel-stars'): 1,
#          ('hotel-area', 'hotel-pricerange', 'hotel-stars'): 1,
#          ('hotel-internet', 'hotel-pricerange'): 1,
#          ('hotel-internet', 'hotel-name', 'hotel-parking', 'hotel-stars'): 1,
#          ('hotel-area',
#           'hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-internet',
#           'hotel-name',
#           'hotel-stars'): 1,
#          ('hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-parking',
#           'hotel-pricerange',
#           'hotel-stars',
#           'hotel-type'): 1,
#          ('hotel-internet', 'hotel-name', 'hotel-parking'): 1,
#          ('hotel-name', 'hotel-pricerange', 'hotel-stars'): 1,
#          ('hotel-stars', 'hotel-type'): 1,
#          ('hotel-area', 'hotel-internet', 'hotel-stars', 'hotel-type'): 1,
#          ('hotel-area', 'hotel-pricerange'): 1,
#          ('hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-name',
#           'hotel-parking',
#           'hotel-pricerange',
#           'hotel-type'): 1,
#          ('hotel-area', 'hotel-internet', 'hotel-pricerange'): 1,
#          ('hotel-area',
#           'hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-parking',
#           'hotel-stars',
#           'hotel-type'): 1,
#          ('hotel-pricerange', 'hotel-type'): 1,
#          ('train-arriveby', 'train-day', 'train-departure'): 1,
#          ('hotel-pricerange', 'hotel-stars', 'hotel-type'): 1,
#          ('hotel-internet',
#           'hotel-name',
#           'hotel-pricerange',
#           'hotel-stars',
#           'hotel-type'): 1,
#          ('hotel-area',
#           'hotel-internet',
#           'hotel-name',
#           'hotel-parking',
#           'hotel-pricerange'): 1,
#          ('hotel-area',
#           'hotel-bookday',
#           'hotel-internet',
#           'hotel-parking',
#           'hotel-pricerange'): 1,
#          ('restaurant-area',
#           'restaurant-bookday',
#           'restaurant-bookpeople',
#           'restaurant-booktime',
#           'restaurant-food',
#           'restaurant-name'): 1,
#          ('hotel-area',
#           'hotel-name',
#           'hotel-parking',
#           'hotel-pricerange',
#           'hotel-stars'): 1,
#          ('train-departure',): 1,
#          ('train-departure', 'train-destination'): 1,
#          ('hotel-area', 'hotel-internet', 'hotel-parking', 'hotel-type'): 1,
#          ('hotel-area',
#           'hotel-internet',
#           'hotel-name',
#           'hotel-parking',
#           'hotel-type'): 1,
#          ('hotel-area',
#           'hotel-bookstay',
#           'hotel-internet',
#           'hotel-name',
#           'hotel-pricerange',
#           'hotel-stars'): 1,
#          ('hotel-area', 'hotel-name', 'hotel-pricerange'): 1,
#          ('restaurant-area',
#           'restaurant-bookpeople',
#           'restaurant-food',
#           'restaurant-pricerange'): 1,
#          ('restaurant-area',
#           'restaurant-bookday',
#           'restaurant-bookpeople',
#           'restaurant-booktime',
#           'restaurant-name'): 1,
#          ('hotel-parking', 'hotel-pricerange'): 1,
#          ('hotel-parking', 'hotel-pricerange', 'hotel-stars'): 1,
#          ('hotel-area',
#           'hotel-internet',
#           'hotel-pricerange',
#           'hotel-stars'): 1,
#          ('restaurant-bookday',
#           'restaurant-bookpeople',
#           'restaurant-booktime',
#           'restaurant-name',
#           'restaurant-pricerange'): 1,
#          ('hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-internet',
#           'hotel-name',
#           'hotel-parking',
#           'hotel-pricerange'): 1,
#          ('hotel-internet',
#           'hotel-parking',
#           'hotel-pricerange',
#           'hotel-type'): 1,
#          ('hotel-internet',
#           'hotel-name',
#           'hotel-parking',
#           'hotel-pricerange',
#           'hotel-type'): 1,
#          ('hotel-area',
#           'hotel-internet',
#           'hotel-parking',
#           'hotel-pricerange',
#           'hotel-stars',
#           'hotel-type'): 1,
#          ('hotel-area',
#           'hotel-internet',
#           'hotel-name',
#           'hotel-parking',
#           'hotel-pricerange',
#           'hotel-stars',
#           'hotel-type'): 1,
#          ('hotel-area', 'hotel-internet', 'hotel-name', 'hotel-parking'): 1,
#          ('train-bookpeople',
#           'train-day',
#           'train-departure',
#           'train-leaveat'): 1,
#          ('train-arriveby',
#           'train-bookpeople',
#           'train-day',
#           'train-destination'): 1,
#          ('hotel-area',
#           'hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-name',
#           'hotel-parking',
#           'hotel-pricerange',
#           'hotel-stars',
#           'hotel-type'): 1,
#          ('hotel-area', 'hotel-internet', 'hotel-name', 'hotel-pricerange'): 1,
#          ('hotel-area',
#           'hotel-bookday',
#           'hotel-internet',
#           'hotel-name',
#           'hotel-type'): 1,
#          ('hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-internet',
#           'hotel-parking',
#           'hotel-pricerange',
#           'hotel-type'): 1,
#          ('hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-internet',
#           'hotel-parking',
#           'hotel-pricerange',
#           'hotel-stars'): 1,
#          ('train-day', 'train-destination', 'train-leaveat'): 1,
#          ('hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-parking',
#           'hotel-stars',
#           'hotel-type'): 1,
#          ('hotel-area',
#           'hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-name',
#           'hotel-parking',
#           'hotel-stars',
#           'hotel-type'): 1,
#          ('hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-name',
#           'hotel-parking',
#           'hotel-pricerange',
#           'hotel-stars',
#           'hotel-type'): 1,
#          ('hotel-area', 'hotel-name', 'hotel-type'): 1,
#          ('hotel-area',
#           'hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-internet',
#           'hotel-name',
#           'hotel-parking',
#           'hotel-pricerange',
#           'hotel-type'): 1,
#          ('hotel-area',
#           'hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-name',
#           'hotel-pricerange',
#           'hotel-type'): 1,
#          ('hotel-area',
#           'hotel-internet',
#           'hotel-name',
#           'hotel-parking',
#           'hotel-pricerange',
#           'hotel-type'): 1,
#          ('hotel-parking', 'hotel-pricerange', 'hotel-stars', 'hotel-type'): 1,
#          ('hotel-area', 'hotel-name', 'hotel-pricerange', 'hotel-type'): 1,
#          ('hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-name',
#           'hotel-parking',
#           'hotel-pricerange',
#           'hotel-stars'): 1,
#          ('hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-name',
#           'hotel-pricerange',
#           'hotel-stars'): 1,
#          ('hotel-area',
#           'hotel-internet',
#           'hotel-name',
#           'hotel-pricerange',
#           'hotel-stars'): 1,
#          ('hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-internet',
#           'hotel-name',
#           'hotel-parking',
#           'hotel-pricerange',
#           'hotel-stars',
#           'hotel-type'): 1,
#          ('hotel-area',
#           'hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-name',
#           'hotel-parking',
#           'hotel-pricerange'): 1,
#          ('hotel-area',
#           'hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-parking',
#           'hotel-pricerange'): 1,
#          ('train-arriveby',
#           'train-bookpeople',
#           'train-day',
#           'train-destination',
#           'train-leaveat'): 1,
#          ('hotel-area',
#           'hotel-bookday',
#           'hotel-bookpeople',
#           'hotel-bookstay',
#           'hotel-name',
#           'hotel-parking',
#           'hotel-stars'): 1})

# %%
filtered_keys = [element for element, count in Counter(record).items() if count >= 8]
sum([count for element, count in Counter(record).items() if count >= 8])
# Out:
# 513

# %%
len(filtered_keys)
# Out:
# 22

# %%
import json
import os
from dataclasses import dataclass
from collections import defaultdict
from typing import List, Dict
import random

def load_json(file_path):
    with open(file_path, 'r') as f:
        data = json.load(f)
    return data

def save_json(file_path, data):
    with open(file_path, 'w') as f:
        json.dump(data, f, indent=4)

@dataclass
class Turn:
    uid: str
    active_intent: str
    service: str
    slot_values: Dict[str, List[str]]
    conversation: List[Dict[str, str]]


@dataclass
class Dialogue:
    uid: str
    services: List[str]
    turns: List[Turn]


@dataclass
class ReasoningTurn:
    uid: str
    conversation: List[Dict[str, str]]


@dataclass
class ReasoningDialogue:
    uid: str
    if_target: bool
    turns: List[ReasoningTurn]
    mh_keys: List[str]
    mh_question: str
    mh_answer: str
    sh_question: str
    sh_answer: str


@dataclass
class ReasoningGroupDialogue:
    uid: str
    dialogues: List[ReasoningDialogue]
    target_position: int
    postfix_question: str
    multi_choices: List[str]
    groud_truth: str
    

class MultiwozDataset:
    def __init__(self, dataset_folder_path, propotion=1):
        self.raw_data = self.load_from_dir(dataset_folder_path, propotion)
        self.data = self.build_dataset(self.raw_data)
    
    def load_from_dir(self, dir_pth, propotion):
        """
        Load all the json files from a directory and return a list of json data.
        
        Args:
            propotion (float): the propotion of the data to be loaded. Default is 1.
        """
        concat_data = []
        for root, _, files in os.walk(dir_pth):
            for file in files:
                if file.endswith(".json"):
                    concat_data = concat_data + load_json(os.path.join(root, file))
        return concat_data[:int(len(concat_data) * propotion)]
    
    def remove_inconsistency(self, dataset):
        filtered_dataset = []
        for parsed_dialogue in dataset:
            services = parsed_dialogue.services
            real_services = set()
            for turn in parsed_dialogue.turns:
                real_services.add(turn.service)
            
            if sorted(services) == sorted(list(real_services)):
                filtered_dataset.append(parsed_dialogue)

        return filtered_dataset
    
    def build_dataset(self, data):
        multiwoz = []
        for dialogue_id, dialogue in enumerate(data):
            parsed_turns = []
            for conversation_id in range(0, len(dialogue['turns']), 2):
                turn = dialogue['turns'][conversation_id: conversation_id+2]
                user_turn = turn[0]
                system_turn=turn[1]
                for category in user_turn['frames']:
                    state = category['state']
                    slot_values = state['slot_values']
                    if state['active_intent'] == "NONE":
                        continue
                    active_intent = state['active_intent']
                    service = category['service']
                    break
                
                if len(slot_values.keys()) == 0:
                    continue
                
                parsed_turn = Turn(
                    uid=conversation_id,
                    slot_values=slot_values,
                    active_intent=active_intent,
                    service=service,
                    conversation=[
                        {
                            "role": "user",
                            "content": user_turn['utterance'] 
                        },
                        {
                            "role": "assistant",
                            "content": system_turn['utterance']
                        }
                    ]
                )
                parsed_turns.append(parsed_turn)
            
            if len(dialogue['services']) == 2:
            
                parsed_dialogue = Dialogue(
                    uid=dialogue_id,
                    services=tuple(dialogue['services']),
                    turns=parsed_turns
                )
                multiwoz.append(parsed_dialogue)
        
        multiwoz = self.remove_inconsistency(multiwoz)
        
        return multiwoz
            

class MultihopReasoningQA:
    """
    A class for constructing a dataset for multihop reasoning questions and answers from the MultiWOZ dataset.

    Attributes:
        dataset_folder_path (str): The folder path where the dataset is located.
        propotion (float): The proportion of the data to be used from the dataset.
        target_position (int): The target dialogue's position for reasoning tasks.
        window_size (int): The number of dialogues to consider for each reasoning task.
        mode (str): The mode of reasoning, e.g., 'service' or 'intent'.
        n_options (int): The number of options for multiple-choice questions.

    Methods:
        build_options_pool: Builds a pool of options for multiple-choice questions based on the mode.
        build_multiple_choice: Constructs multiple choice options for a given ground truth.
        build_mh_qa: Generates multi-hop reasoning questions and answers.
        build_sh_qa: Generates single-hop reasoning questions and answers.
        build_dataset: Assembles the dataset for reasoning tasks.
    """
    def __init__(
        self,
        dataset_folder_path,
        propotion,
        target_position,
        window_size,
        mode="service",
        n_options=4,
        seed=42
    ):
        self.dataset_foler_path = dataset_folder_path
        self.target_position = target_position
        self.window_size = window_size
        self.mode = mode
        self.n_options = n_options
        
        random.seed(seed)

        self.multiwoz = MultiwozDataset(dataset_folder_path=dataset_folder_path,propotion=propotion)
        self.options_pool = self.build_options_pool(self.multiwoz, mode)
        self.group_dataset = self.build_dataset()

    def build_options_pool(self, dataset: MultiwozDataset, mode) -> List[str]:
        options_pool = []
        if mode == "service":
            for dialogue in dataset.data:
                options_pool.append(",".join(dialogue.services))
        elif mode == "intent":
            for dialogue in dataset.data:
                continue
            
        elif mode == "inference":
            for dialogue in dataset.data:
                options_pool.extend(dialogue.services)
        
        else:
            raise NotImplementedError
            
        return list(set(options_pool))

    def build_multiple_choice(self, n_options: int, groud_truth: str, options_pool: List[str]) -> List[str]:
        
        options_pool.remove(groud_truth)
        options_without_gt = random.sample(options_pool, n_options - 1)
        
        full_options = options_without_gt
        full_options.append(groud_truth)
        random.shuffle(full_options)
        
        options_pool.append(groud_truth)
        
        return full_options
    
    def build_mh_qa(self, dialogue: Dialogue, mode="intent"):
        mh_question = ""
        mh_answer = ""
        
        if mode == "intent":
            mh_question = f"what does user intent to do according to the dialogue {self.target_position}?"
            mh_answer = ",".join(list(set([turn.active_intent for turn in dialogue.turns])))
        elif mode == "service":
            mh_question = f"what are the services the [dialogue {self.target_position}] contain?"
            mh_answer = ",".join(dialogue.services)
        elif mode == "inference":
            mh_question = ""
            mh_answer = ""
            options = ["isn't", "is"]
            answers = ["no", "yes"]
            if len(dialogue.services) != 2:
                mh_question = None
                mh_answer = None
            else:
                services = list(dialogue.services)
                turns_by_service = defaultdict(list)
                for turn in dialogue.turns:
                    turns_by_service[turn.service].append(turn)
                src_service = random.sample(services, 1)[0]
                services.remove(src_service)
                tar_service = services[0]
                
                src_turn = turns_by_service[src_service]
                tar_turn = turns_by_service[tar_service]
                
                src_request = list(src_turn[0].slot_values.values())[0][0] + " " + src_turn[0].service
                
                option_idx = random.randint(0, 1)
                option = options[option_idx]
                
                # mh_question = f"Is the statement correct? statement: In the dialogue [{self.target_position}], the user request for a {src_request}, another topic user ask for {option} {tar_service}. Answer(yes/no):"
                mh_question = f"In the dialogue [{self.target_position}], the user request for a {src_request}. What is the other topic user talk about?\n Answer in a word:"
                mh_answer = tar_service
            
        else:
            raise NotImplementedError
        
        return mh_question, mh_answer
    
    def build_sh_qa(self, dialogue: Dialogue):
        sh_question = ""
        sh_answer = ""
        
        return sh_question, sh_answer

    def build_dataset(self):
        window_size = self.window_size
        position = self.target_position
        dataset = self.multiwoz.data
        group_dataset = []
        for group_id in range(0, len(dataset), window_size):
            if group_id + window_size > len(dataset):
                continue
            group_dialogues: List[Dialogue] = dataset[group_id: group_id+window_size]
            group_reasoning_dialogues = []
            for dialogue_id, dialogue in enumerate(group_dialogues):
                reasoning_turns = []
                for turn in dialogue.turns:
                    reasoning_turns.append(ReasoningTurn(
                        uid=turn.uid,
                        conversation=turn.conversation
                    ))
                
                mh_question, mh_answer = self.build_mh_qa(dialogue, mode=self.mode)
                sh_question, sh_answer = self.build_sh_qa(dialogue)    
                
                
                group_reasoning_dialogues.append(ReasoningDialogue(
                    uid=dialogue_id,
                    turns=reasoning_turns,
                    mh_keys=None,
                    mh_question=mh_question,
                    mh_answer=mh_answer,
                    sh_question=sh_question,
                    sh_answer=sh_answer,
                    if_target= str(dialogue.uid) == str(position)
                ))
            

            postfix_question = group_reasoning_dialogues[self.target_position].mh_question
            groud_truth = group_reasoning_dialogues[self.target_position].mh_answer

            multi_choices = self.build_multiple_choice(self.n_options, groud_truth, self.options_pool)

            
            
            group_dataset.append(ReasoningGroupDialogue(
                uid=group_id,
                dialogues=group_reasoning_dialogues,
                target_position=self.target_position,
                postfix_question=postfix_question,
                multi_choices=multi_choices,
                groud_truth=groud_truth
            ))
        
        return group_dataset
    
    def save_as_json(self, root_path, mode="inference"):
        formatted_dataset = []
        options_and_gts = []
        for grouped_dialogue in self.group_dataset:
            formatted_group_dialogue = []

            for dialogue in grouped_dialogue.dialogues:
                for turn in dialogue.turns:
                    turn.conversation[0]['content'] = f"[dialogue {dialogue.uid}] " + turn.conversation[0]['content']
                    formatted_group_dialogue.extend(turn.conversation)
            
            target_dialogue = grouped_dialogue.dialogues[self.target_position]
            
            formatted_group_dialogue.append({
                "role": "user",
                "content": target_dialogue.mh_question
            })
            
            options_and_gts.append({
                "options": grouped_dialogue.multi_choices,
                "gt": target_dialogue.mh_answer
            })
            
            formatted_dataset.append(formatted_group_dialogue)
        
        with open(os.path.join(root_path, f"multiwoz-{self.window_size}-{self.target_position}-{self.mode}.json"), 'w') as f:
            json.dump(formatted_dataset, f, indent=4)
            
        with open(os.path.join(os.path.join(root_path, "labels"), f"multiwoz-{self.window_size}-{self.target_position}-label-{self.mode}.json"), 'w') as f:
            json.dump(options_and_gts, f, indent=4)

# %%
dataset_mh = MultihopReasoningQA(
    dataset_folder_path="/home/eidf018/eidf018/s2484588-epcc/MLP/LLMMemoryEval/datasets/data/multiwoz/clean_data",
    propotion=1,
    target_position=0,
    window_size=3,
    mode="inference"
)
dataset_mh.save_as_json(root_path="/home/eidf018/eidf018/s2484588-epcc/MLP/LLMMemoryEval/datasets/data/multiwoz")

dataset_mh = MultihopReasoningQA(
    dataset_folder_path="/home/eidf018/eidf018/s2484588-epcc/MLP/LLMMemoryEval/datasets/data/multiwoz/clean_data",
    propotion=1,
    target_position=0,
    window_size=4,
    mode="inference"
)
dataset_mh.save_as_json(root_path="/home/eidf018/eidf018/s2484588-epcc/MLP/LLMMemoryEval/datasets/data/multiwoz")

dataset_mh = MultihopReasoningQA(
    dataset_folder_path="/home/eidf018/eidf018/s2484588-epcc/MLP/LLMMemoryEval/datasets/data/multiwoz/clean_data",
    propotion=1,
    target_position=0,
    window_size=5,
    mode="inference"
)
dataset_mh.save_as_json(root_path="/home/eidf018/eidf018/s2484588-epcc/MLP/LLMMemoryEval/datasets/data/multiwoz")

# %%
idx = 0

# %%
dataset_mh.group_dataset[idx].dialogues
# Out:
# [ReasoningDialogue(uid=0, if_target=True, turns=[ReasoningTurn(uid=0, conversation=[{'role': 'user', 'content': 'I need a train going to Cambridge that will depart after 10:15 from broxbourne.'}, {'role': 'assistant', 'content': 'I have train TR5678 that would suit you.'}]), ReasoningTurn(uid=2, conversation=[{'role': 'user', 'content': 'Could you just tell me when that one departs?'}, {'role': 'assistant', 'content': 'Train TR5678 departs Broxbourne at 10:32 and arrives at Cambridge at 11:32.'}]), ReasoningTurn(uid=4, conversation=[{'role': 'user', 'content': 'Great can you get me a booking for 3 people?'}, {'role': 'assistant', 'content': 'Booked! Your reference number is: XZU4Z1RR . Can I help with anything else?'}]), ReasoningTurn(uid=6, conversation=[{'role': 'user', 'content': 'Thank you. Yes. I am also looking for an international restaurant.'}, {'role': 'assistant', 'content': 'There are three. Two located in the centre that are moderate in price and one in the east that is cheap.'}]), ReasoningTurn(uid=8, conversation=[{'role': 'user', 'content': 'I want the one in the east, please book me a table for 3 people.'}, {'role': 'assistant', 'content': 'Certainly. Can you please tell me for what day you would like for me to make this reservation?'}]), ReasoningTurn(uid=10, conversation=[{'role': 'user', 'content': 'can you book it for sunday afternoon?'}, {'role': 'assistant', 'content': 'What time exactly would you like to dine?'}]), ReasoningTurn(uid=12, conversation=[{'role': 'user', 'content': "Actually, I'd like a moderately priced international restaurant in the centre. I need the postcode and address please. Sorry, I keep changing my request!"}, {'role': 'assistant', 'content': 'No problem. How about The Varsity Restaurant located at 35 Saint Andrews Street City Centre with phone number 01223356060? There is also Bloomsbury Restaurant if you prefer.'}]), ReasoningTurn(uid=14, conversation=[{'role': 'user', 'content': 'The Varsity is good. Can I get the postcode please?'}, {'role': 'assistant', 'content': 'The post code is cb23ar. Shall I book it ?'}]), ReasoningTurn(uid=16, conversation=[{'role': 'user', 'content': 'Yes, please make the booking and email me the reference number.'}, {'role': 'assistant', 'content': 'How many people will the reservation be for?'}])], mh_keys=None, mh_question='In the dialogue 0, the user request for a international restaurant, another service user ask for is train. Is the statement correct?', mh_answer=True, sh_question='', sh_answer=''),
#  ReasoningDialogue(uid=1, if_target=False, turns=[ReasoningTurn(uid=0, conversation=[{'role': 'user', 'content': "It's Sunday and I am bored. Do you have any trains into Cambridge today?"}, {'role': 'assistant', 'content': 'There are many trains, when would you like to depart?'}]), ReasoningTurn(uid=2, conversation=[{'role': 'user', 'content': 'I would like to leave from Kings Lynn after 9:30.'}, {'role': 'assistant', 'content': 'TR5928 leaves at 10:11, would you like me to book that for you?'}]), ReasoningTurn(uid=4, conversation=[{'role': 'user', 'content': 'Can you give me the price of a ticket?'}, {'role': 'assistant', 'content': 'Tickets are 7.84 pounds. Can I book that for you?'}]), ReasoningTurn(uid=6, conversation=[{'role': 'user', 'content': "Great I also need to find a place to stay that doesn't need to have free parking and is in the cheap price range."}, {'role': 'assistant', 'content': 'There are 33 hotels in the cheap range, any preference on area or anything else?'}]), ReasoningTurn(uid=8, conversation=[{'role': 'user', 'content': 'Cheap price range in the centre.'}, {'role': 'assistant', 'content': 'There are two choices. Alexander Bed and Breakfast and El Shaddai. Do you want to make a reservation at one of these choices?'}]), ReasoningTurn(uid=10, conversation=[{'role': 'user', 'content': 'I will take Alexander please.'}, {'role': 'assistant', 'content': 'To confirm you want me to book you a room at Alexander Bed and Breakfast starting on Sunday. How many nights will you be staying?'}]), ReasoningTurn(uid=12, conversation=[{'role': 'user', 'content': 'Yes. Please book it for 2 people for 2 nights on Sunday.'}, {'role': 'assistant', 'content': "I'm sorry, Alexander Bed and Breakfast is unavailable for those nights. Would you like to try another day or just one night instead?"}]), ReasoningTurn(uid=14, conversation=[{'role': 'user', 'content': "Actually, let's back up. I need a place with a star rating of 0, in the centre, with free parking. Does the Alexander have 0 stars?"}, {'role': 'assistant', 'content': 'I have the El Shaddai that is cheap and located in the centre. They have a 0 star rating and offer free parking and free wifi. Would that work for you?'}]), ReasoningTurn(uid=16, conversation=[{'role': 'user', 'content': 'Yes, that would work for me. Please book it for 2 people for 2 nights starting sunday.'}, {'role': 'assistant', 'content': "I'm sorry i was unable to book your table for 2 people for 2 days on sunday. Would you like another day?"}]), ReasoningTurn(uid=18, conversation=[{'role': 'user', 'content': 'How about trying just for one night, instead?'}, {'role': 'assistant', 'content': 'Booking was successful for 1 night only. Reference number is : O1RX0UHA . Can I be of anything further assistance?'}])], mh_keys=None, mh_question='In the dialogue 0, the user request for a sunday train, another service user ask for is hotel. Is the statement correct?', mh_answer=True, sh_question='', sh_answer=''),
#  ReasoningDialogue(uid=2, if_target=False, turns=[ReasoningTurn(uid=0, conversation=[{'role': 'user', 'content': 'I am looking for places to go in town I prefer a college.'}, {'role': 'assistant', 'content': "How about Magdalene College? They're in the west side, and they have no entrance fee."}]), ReasoningTurn(uid=2, conversation=[{'role': 'user', 'content': 'That sounds perfect. What is their address?'}, {'role': 'assistant', 'content': 'Their postcode is cb30ag an the entrance is free.'}]), ReasoningTurn(uid=4, conversation=[{'role': 'user', 'content': "Okay what's their address?"}, {'role': 'assistant', 'content': 'The address is magdalene street. Would you like the phone number also?'}]), ReasoningTurn(uid=6, conversation=[{'role': 'user', 'content': 'No on the phone number. I now need help finding a cheap restaurant in the centre of the town.'}, {'role': 'assistant', 'content': "There are many restaurants, do you know what sort of food you're looking for?"}]), ReasoningTurn(uid=8, conversation=[{'role': 'user', 'content': 'I have no preference on type of food.'}, {'role': 'assistant', 'content': 'Would you like dojo noodle bar?'}]), ReasoningTurn(uid=10, conversation=[{'role': 'user', 'content': 'Sure. Can I get the phone number?'}, {'role': 'assistant', 'content': 'Yes, their phone number is 01223363471. Would you like me to book a table for you?'}]), ReasoningTurn(uid=14, conversation=[{'role': 'user', 'content': 'I would like to go from the Dojo Noodle Bar to Magdalene College. I want to leave the restaurant by 12:15.'}, {'role': 'assistant', 'content': "I've booked a car to take you from Dojo to Magdalene College. The vehicle is a white Honda, the contact number is 07882764497. Do you require anything else?"}])], mh_keys=None, mh_question=None, mh_answer=None, sh_question='', sh_answer='')]

# %%
dataset_mh.group_dataset[idx].dialogues[dataset_mh.target_position].mh_question
# Out:
# 'In the dialogue 0, the user request for a broxbourne train, another service user ask for is restaurant. Is the statement correct?'

# %%
dataset_mh.group_dataset[idx].postfix_question
# Out:
# 'what are the services the dialogue 0 contain?'

# %%
dataset_mh.group_dataset[idx].groud_truth
# Out:
# 'restaurant,hotel'

# %%
dataset_mh.group_dataset[idx].multi_choices
# Out:
# ['attraction,taxi',
#  'restaurant,hotel',
#  'restaurant,attraction',
#  'restaurant,train']
